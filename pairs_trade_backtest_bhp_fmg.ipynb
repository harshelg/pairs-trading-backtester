# %%
# !pip install yfinance statsmodels
# Out:
# Requirement already satisfied: yfinance in /opt/anaconda3/lib/python3.14/site-packages (1.7.0)
# Requirement already satisfied: statsmodels in /opt/anaconda3/lib/python3.14/site-packages (0.14.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/anaconda3/lib/python3.14/site-packages (from yfinance) (4.15.0)
# Requirement already satisfied: curl_cffi>=0.15 in /opt/anaconda3/lib/python3.14/site-packages (from yfinance) (0.16.3)
# Requirement already satisfied: lxml>=4.9.0 in /opt/anaconda3/lib/python3.14/site-packages (from yfinance) (6.1.0)
# Requirement already satisfied: multitasking>=0.0.7 in /opt/anaconda3/lib/python3.14/site-packages (from yfinance) (0.0.13)
# Requirement already satisfied: numpy>=1.16.5 in /opt/anaconda3/lib/python3.14/site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: pandas>=1.3.0 in /opt/anaconda3/lib/python3.14/site-packages (from yfinance) (3.0.3)
# Requirement already satisfied: peewee>=3.16.2 in /opt/anaconda3/lib/python3.14/site-packages (from yfinance) (4.5.0)
# Requirement already satisfied: platformdirs>=2.0.0 in /opt/anaconda3/lib/python3.14/site-packages (from yfinance) (4.9.4)
# Requirement already satisfied: protobuf>=3.19.0 in /opt/anaconda3/lib/python3.14/site-packages (from yfinance) (6.33.5)
# Requirement already satisfied: pytz>=2022.5 in /opt/anaconda3/lib/python3.14/site-packages (from yfinance) (2026.2)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/lib/python3.14/site-packages (from yfinance) (2.34.2)
# Requirement already satisfied: websockets>=13.0 in /opt/anaconda3/lib/python3.14/site-packages (from yfinance) (16.0)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /opt/anaconda3/lib/python3.14/site-packages (from statsmodels) (1.18.0)
# Requirement already satisfied: patsy>=0.5.6 in /opt/anaconda3/lib/python3.14/site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in /opt/anaconda3/lib/python3.14/site-packages (from statsmodels) (26.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /opt/anaconda3/lib/python3.14/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/anaconda3/lib/python3.14/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.16.0)
# Requirement already satisfied: cffi>=2.0.0 in /opt/anaconda3/lib/python3.14/site-packages (from curl_cffi>=0.15->yfinance) (2.1.0)
# Requirement already satisfied: certifi>=2024.2.2 in /opt/anaconda3/lib/python3.14/site-packages (from curl_cffi>=0.15->yfinance) (2026.7.22)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.14/site-packages (from cffi>=2.0.0->curl_cffi>=0.15->yfinance) (3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.14/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.14/site-packages (from requests>=2.31->yfinance) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.14/site-packages (from requests>=2.31->yfinance) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/anaconda3/lib/python3.14/site-packages (from requests>=2.31->yfinance) (2.7.0)

# %%
# Written by Harshel Gopiinaath, last updated 06/09/2026
# z5764696@ad.unsw.edu.au
# A pair trading strategy backtester based on past data from the stock market

import yfinance as fins
import numpy as np
import statsmodels.api as stat
from statsmodels.tsa.stattools import coint
import matplotlib.pyplot as plot
import pandas as pd

# %%
# Get data on two stocks via yfinance

ticker1 = "BHP.AX" # PICK ANY TICKER PAIR!
ticker2 = "FMG.AX"

data1 = fins.download(ticker1, start="2015-01-01", end="2024-01-01")
data2 = fins.download(ticker2, start="2015-01-01", end="2024-01-01")

close1 = data1["Close"][ticker1]
close2 = data2["Close"][ticker2]
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
# Test cointegration of our two stocks

score, p_value, _ = coint(close1, close2)
print(p_value)
# Out:
# 0.3654189251266658

# %%
# Check whether this pair actually clears a standard significance threshold for cointegration - the backtest below still runs either way (useful for comparing candidate pairs), but a low p-value means the pair is a good mean-reversion candidate.

ALPHA = 0.05
if p_value >= ALPHA:
    print(f"⚠️  WARNING: p-value = {p_value:.4f} >= {ALPHA} -- no statistically significant "
          f"cointegration found between {ticker1} and {ticker2}. Proceeding with the backtest "
          f"below anyway for comparison, but treat the results with caution.")
else:
    print(f"p-value = {p_value:.4f} < {ALPHA} -- {ticker1} and {ticker2} show statistically "
          f"significant cointegration.")

# %%
# Finding the hedge ratio of our stocks and converting the associated spread into a z-score

X = stat.add_constant(close2)
model = stat.OLS(close1, X).fit()
hedge_ratio = model.params.iloc[1]

spread = close1 - hedge_ratio * close2

# %%
# Conversion to z-score

window = 60 # days, can experiment with this
spread_mean = spread.rolling(window).mean()
spread_std = spread.rolling(window).std()
zscore = (spread - spread_mean) / spread_std

# %%
# IMPORTANT! Check our close1 data type (behaviour of Yahoo Finance data is different for different years)

print(data1.columns)
print(type(close1))
# Out:
# MultiIndex([( 'Close', 'BHP.AX'),
#             (  'High', 'BHP.AX'),
#             (   'Low', 'BHP.AX'),
#             (  'Open', 'BHP.AX'),
#             ('Volume', 'BHP.AX')],
#            names=['Price', 'Ticker'])
# <class 'pandas.Series'>

# %%
# Backtest our trading based on these signals

positions = []
position = 0 # 0 is flat, 1 is long spread, -1 is short spread

for z in zscore:
    if position == 0:
        if z > 2:
            position = -1 # spread is wider than expected, short first and long second

        elif z < -2:
            position = 1 # spread is narrower than expected, long first and short second
    elif position == 1 and z >= 0:
        position = 0 # close our long position

    elif position == -1 and z <= 0:
        position = 0 # close our short position

    positions.append(position)

positions = pd.Series(positions, index=zscore.index)

spread_returns = spread.diff()
strategy_returns = positions.shift(1) * spread_returns
cumulative_returns = strategy_returns.cumsum()

# Annualise the Sharpe ratio to account for days traded (sqrt 252 as variance is additive and 252 days traded on market)
sharpe_ratio = (strategy_returns.mean() / strategy_returns.std()) * np.sqrt(252)
max_drawdown = (cumulative_returns.cummax() - cumulative_returns).max()

print("Sharpe ratio (annualized):", sharpe_ratio)
print("Max drawdown:", max_drawdown)
# Out:
# Sharpe ratio (annualized): -0.20076899430428818
# Max drawdown: 10.834154291264817

# %%
# Visualise our results using plots

plot.figure(figsize=(10, 5))
cumulative_returns.plot()
plot.title("Cumulative Returns from Pair Trading Strategy")
plot.show()
